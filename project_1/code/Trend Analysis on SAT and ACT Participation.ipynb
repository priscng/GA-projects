# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Analyse the SAT and ACT participation rates and scores from 2017 to 2019 and provide recommendations to improve SAT participation rates.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **Further information:**
# - The SAT test total score range is 400 to 1600. Total score is the sum of Evidence-Based Reading and Writing (ERW) section and the Math section score. Each section has a score range of 200 to 800 [(source)](https://blog.collegeboard.org/whats-a-good-sat-score).
# - Students can take the test more than once. Many colleges superscore the SAT score where it takes the best score, even if they were from different tests [(source)](https://blog.collegeboard.org/what-is-an-sat-superscore).
# - The ACT Composite score range is 1 to 36. This score is an average of all the subject area scores, rounded up to
# the nearest whole number. The subject areas are English, Maths, Science and Reading [(source)](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html).
# - ACT and the College Board have done a study and provide the concordance tables to compare ACT and SAT scores [(source)](https://www.act.org/content/act/en/products-and-services/the-act/scores/act-sat-concordance.html).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **Datasets chosen:**
# - act_2017.csv
# - act_2018.csv
# - act_2019.csv
# - sat_2017.csv
# - sat_2018.csv
# - sat_2019.csv
#
# **Brief information of the datasets:**
# - The chosen datasets contain information on the ACT and SAT scores by state from 2017 to 2019. The data will be used to compare the ACT and SAT scores and to identify the states with declining participation rate and provide recommendations.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **States that requires SAT:** ([source](https://blog.prepscholar.com/which-states-require-the-sat))
# - Colorado
# - Connecticut
# - Delaware
# - District of Columbia (not compulsory but offered for free in Washington, DC)
# - Idaho (offers a free administration of the SAT to high school juniors)
# - Illinois
# - Michigan (switch from ACT to SAT from 2016)
# - New Hampshire
# - Ohio (either SAT or ACT)
# - Oklahoma (either SAT or ACT)
# - Rhode Island
# - South Carolina (either SAT or ACT)
# - Tennessee (either SAT or ACT)
# - West Virginia
#
# **States that requires ACT:** ([source](https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice))
# - Alabama (requires Writing)
# - Hawaii (requires Writing)
# - Montana (requires Writing)
# - Nebraska (requires Writing)
# - Nevada (requires Writing)
# - North Carolina (requires Writing)
# - North Dakota (requires Writing)
# - Utah (requires Writing)
# - Wisconsin (requires Writing)
# - Kentucky
# - Louisiana
# - Mississippi
# - Wyoming
# - Minnesota (either SAT or ACT)
# - Ohio (either SAT or ACT)
# - Oklahoma (either SAT or ACT)
# - South Carolina(either SAT or ACT)
# - Tennessee(either SAT or ACT)
#
# **Test fees:**
# - [SAT](https://satsuite.collegeboard.org/sat/registration/fee-waivers) and [ACT](https://www.act.org/content/act/en/products-and-services/the-act/registration/fees/fee-waivers.html) both offer test fee wavier for eligible students.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Function to calculate mean
def mean(num_list):
    total = 0
    for number in num_list:
        total += number
    return total / len(num_list)

# %%
# Test function
mean([2, 4, 6, 8, 10, 12])
# Out:
# 7.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Function to calculate standard deviation
def std_dev(num_list):
    average = mean(num_list)
    summation = 0
    for number in num_list:
        summation += (number - average)**2
    return round((summation / len(num_list))**0.5,4)

# %%
# Test function
std_dev([2, 4, 6, 8, 10, 12])
# Out:
# 3.4157

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Function to convert a number string with percentage symbol to a float
def string_to_float(number):
    return float(number.replace('%', '')) / 100

# %%
# Test function
print(string_to_float('30.5%'))
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Import the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
from functools import reduce
sns.set()
sns.set_theme(style='white') # set theme to be white

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# #### SAT dataset

# %%
# Read the data
sat_2019 = pd.read_csv('../data/sat_2019.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')

# %%
# Display the first 5 rows for sat_2019
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
# Display the first 5 rows for sat_2018
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
# Display the first 5 rows for sat_2017
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# Check preliminary info for sat_2019
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
# Check preliminary info for sat_2018
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Check preliminary info for sat_2017
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %% [markdown]
# **SAT datasets preliminary findings:**
# - All datasets have 5 columns, 2 categorical and 3 numerical data type.
# - Participation rate should be a numerical/float data type. Currently, it is an object data type. We will need to check on this column and convert it to the correct data type later.
# - All datasets have 51 rows except for sat_2019 (53 rows). 2019 dataset has 2 additional data which could be duplicate or incorrect since there are 50 States and the District of Columbia. The additional 2 data will have to be identified and removed.
# - No missing values observed for all datasets.

# %%
# Rename the columns for sat_2019
sat_2019.rename(columns = {'State':'state', 'Participation Rate':'sat_participation_2019','EBRW':'ebrw_2019', \
                           'Math':'math_2019', 'Total':'sat_total_2019'}, inplace = True)
sat_2019.head()
# Out:
#         state sat_participation_2019  ebrw_2019  math_2019  sat_total_2019
# 0     Alabama                     7%        583        560            1143
# 1      Alaska                    41%        556        541            1097
# 2     Arizona                    31%        569        565            1134
# 3    Arkansas                     6%        582        559            1141
# 4  California                    63%        534        531            1065

# %%
# Rename the columns for sat_2018
sat_2018.rename(columns = {'State':'state', 'Participation':'sat_participation_2018',\
                           'Evidence-Based Reading and Writing':'ebrw_2018', \
                           'Math':'math_2018', 'Total':'sat_total_2018'}, inplace = True)
sat_2018.head()
# Out:
#         state sat_participation_2018  ebrw_2018  math_2018  sat_total_2018
# 0     Alabama                     6%        595        571            1166
# 1      Alaska                    43%        562        544            1106
# 2     Arizona                    29%        577        572            1149
# 3    Arkansas                     5%        592        576            1169
# 4  California                    60%        540        536            1076

# %%
# Rename the columns for sat_2017
sat_2017.rename(columns = {'State':'state', 'Participation':'sat_participation_2017',\
                           'Evidence-Based Reading and Writing':'ebrw_2017', \
                           'Math':'math_2017', 'Total':'sat_total_2017'}, inplace = True)
sat_2017.head()
# Out:
#         state sat_participation_2017  ebrw_2017  math_2017  sat_total_2017
# 0     Alabama                     5%        593        572            1165
# 1      Alaska                    38%        547        533            1080
# 2     Arizona                    30%        563        553            1116
# 3    Arkansas                     3%        614        594            1208
# 4  California                    53%        531        524            1055

# %%
# Check the SAT min and max values for each dataset
sat_dfs = [sat_2019, sat_2018, sat_2017]

print("Maximum values of SAT scores")
for df in sat_dfs:
    for column in df.columns:
        if df[column].dtypes != object:
             print(f'{column}: {df[column].max()}')
    print()
    
print("Minimum values of SAT scores")
for df in sat_dfs:
    for column in df.columns:
        if df[column].dtypes != object:
             print(f'{column}: {df[column].min()}')
    print()
# Out:
# Maximum values of SAT scores
# ebrw_2019: 636
# math_2019: 648
# sat_total_2019: 1284
#
# ebrw_2018: 643
# math_2018: 655
# sat_total_2018: 1298
#
# ebrw_2017: 644
# math_2017: 651
# sat_total_2017: 1295
#
# Minimum values of SAT scores
# ebrw_2019: 483
# math_2019: 445
# sat_total_2019: 935
#
# ebrw_2018: 480
# math_2018: 480
# sat_total_2018: 977
#
# ebrw_2017: 482
# math_2017: 52
# sat_total_2017: 950

# %% [markdown]
# - The score range for the SAT is 400−1600. This score is the sum of Evidence-Based Reading and Writing (EBRW) and the Math section, where each have a score range of 200−800. It was observed that the Math min score for 2017 is 52 and this is not within the SAT Math score range. However, the total score does not seem to have any abnormality. We will retrieve which row has the Math score of 52.

# %%
# Retreive the row where the math score is 52
sat_2017[sat_2017['math_2017'] == 52]
# Out:
#        state sat_participation_2017  ebrw_2017  math_2017  sat_total_2017
# 20  Maryland                    69%        536         52            1060

# %% [markdown]
# - The Math score for Maryland is 52. However, the total SAT score is 1060 and this is within the SAT total score range. If the total score minus the EBRW score, the Math score will be 524. A further check on the [National Center for Education Statistics website](https://nces.ed.gov/programs/digest/d17/tables/dt17_226.40.asp) verifies that the data is 524. Hence, we will update it to 524.

# %%
# Update the sat_2017 Math score to 524
sat_2017['math_2017'] = sat_2017['math_2017'].replace(52, 524)
sat_2017[sat_2017['math_2017'] == 524]
# Out:
#            state sat_participation_2017  ebrw_2017  math_2017  sat_total_2017
# 4     California                    53%        531        524            1055
# 20      Maryland                    69%        536        524            1060
# 39  Rhode Island                    71%        539        524            1062

# %%
# Check if there any duplicate rows for sat_2019
sat_2019.duplicated().sum()
# Out:
# 0

# %%
# Check which row for sat_2019 is not the same as other datasets.
state_2019 = sat_2019['state']
state_2018 = sat_2018['state']
state_2019.apply(tuple,1).isin(state_2018.apply(tuple, 1))
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39    False
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47    False
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# Name: state, dtype: bool

# %%
sat_2019.tail(14)
# Out:
#              state sat_participation_2019  ebrw_2019  math_2019  \
# 39     Puerto Rico                      —        483        462
# 40    Rhode Island                   100%        503        492
# 41  South Carolina                    68%        526        504
# 42    South Dakota                     3%        633        635
# 43       Tennessee                     7%        618        602
# 44           Texas                    68%        515        507
# 45            Utah                     4%        614        615
# 46         Vermont                    66%        560        546
# 47  Virgin Islands                      —        490        445
# 48        Virginia                    68%        567        551
# 49      Washington                    70%        539        535
# 50   West Virginia                    99%        483        460
# 51       Wisconsin                     3%        635        648
# 52         Wyoming                     3%        623        615
#
# ...

# %% [markdown]
# - Row 39 and 47 for sat_2019 were found to be different and a check on the data below shows 'Puerto Rico' and 'Virgin Islands' are in the other sat files correct states. These rows will be removed when an inner merge to 1 file for all the datasets is done later.

# %% [markdown]
# #### ACT dataset

# %%
# Read the data
act_2019 = pd.read_csv('../data/act_2019.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2017 = pd.read_csv('../data/act_2017.csv')

# %%
# Display the first 5 rows for act_2019
act_2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
# Display the first 5 rows for act_2018
act_2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# Display the first 5 rows for act_2017
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# Check preliminary info for act_2019
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# Check preliminary info for sat_2018
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# Check preliminary info for act_2017
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# **ACT datasets preliminary findings:**
# - act_2019 and act_2018 have 3 columns, 2 categorical and 1 float data type.
# - act_2017 has 7 columns with individual test score data. There are 3 categorical and 4 float data type. We will remove the individual test score columns as the other 2 datasets do not have these data.
# - Participation rate (for all datasets) and Composite score (for act_2017 only) should be a numerical/float data type. Currently, they are object data type. We will need to check on this column and convert it to the correct data type later.
# - All datasets have 52 rows. As sat datasets has 51 rows, there is 1 additional row in all the act datasets which need to be identified and removed.
# - No missing values observed for all datasets.
# - The Composite score and each test score range from 1 to 36. As the Composite score for act_2017 dataset is currently an object data type, we will need to rectify this first before we can see the min and max range of the score.

# %%
# Drop the English, Math, Reading and Science columns as these data are not available in 2018 and 2019 datasets
act_2017.drop(act_2017.loc[:, 'English':'Science'], axis = 1, inplace = True)
act_2017.head()
# Out:
#       State Participation Composite
# 0  National           60%      21.0
# 1   Alabama          100%      19.2
# 2    Alaska           65%      19.8
# 3   Arizona           62%      19.7
# 4  Arkansas          100%      19.4

# %%
# Rename the columns for act_2019
act_2019.rename(columns = {'State':'state', 'Participation':'act_participation_2019', 'Composite':'act_composite_2019'},\
                inplace = True)
act_2019.head()
# Out:
#         state act_participation_2019  act_composite_2019
# 0     Alabama                   100%                18.9
# 1      Alaska                    38%                20.1
# 2     Arizona                    73%                19.0
# 3    Arkansas                   100%                19.3
# 4  California                    23%                22.6

# %%
# Rename the columns for act_2018
act_2018.rename(columns = {'State':'state', 'Participation':'act_participation_2018', 'Composite':'act_composite_2018'},\
                inplace = True)
act_2018.head()
# Out:
#         state act_participation_2018  act_composite_2018
# 0     Alabama                   100%                19.1
# 1      Alaska                    33%                20.8
# 2     Arizona                    66%                19.2
# 3    Arkansas                   100%                19.4
# 4  California                    27%                22.7

# %%
# Rename the columns for act_2017
act_2017.rename(columns = {'State':'state', 'Participation':'act_participation_2017', 'Composite':'act_composite_2017'},\
                inplace = True)
act_2017.head()
# Out:
#       state act_participation_2017 act_composite_2017
# 0  National                    60%               21.0
# 1   Alabama                   100%               19.2
# 2    Alaska                    65%               19.8
# 3   Arizona                    62%               19.7
# 4  Arkansas                   100%               19.4

# %%
# Check which Composite score is having issue
for index, score in enumerate(act_2017['act_composite_2017']):
    try:
        float(score)
    except ValueError:
        print(index, score)
# Out:
# 51 20.2x

# %%
# Identify the state with 20.2x 
act_2017.loc[51]
# Out:
# state                     Wyoming
# act_participation_2017       100%
# act_composite_2017          20.2x
# Name: 51, dtype: object

# %% [markdown]
# The Composite score for Wyoming is 20.2x. A further check on the [National Center for Education Statistics website](https://nces.ed.gov/programs/digest/d17/tables/dt17_226.60.asp) verifies that the data is 20.2. Hence, we will update it to 20.2.

# %%
# Update the act_2017 Composite score to 20.2
act_2017['act_composite_2017'] = act_2017['act_composite_2017'].replace('20.2x', 20.2)
act_2017[act_2017['act_composite_2017'] == 20.2]
# Out:
#       state act_participation_2017 act_composite_2017
# 51  Wyoming                   100%               20.2

# %%
act_2017['act_composite_2017'] = act_2017['act_composite_2017'].astype(float)
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   52 non-null     object
#  1   act_participation_2017  52 non-null     object
#  2   act_composite_2017      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# Check the ACT min and max values for each dataset
act_dfs = [act_2019, act_2018, act_2017]

print("Maximum values of ACT scores")
for df in act_dfs:
    for column in df.columns:
        if df[column].dtypes != object:
             print(f'{column}: {df[column].max()}')
print()

print("Minimum values of ACT scores")
for df in act_dfs:
    for column in df.columns:
        if df[column].dtypes != object:
             print(f'{column}: {df[column].min()}')
# Out:
# Maximum values of ACT scores
# act_composite_2019: 25.5
# act_composite_2018: 25.6
# act_composite_2017: 25.5
#
# Minimum values of ACT scores
# act_composite_2019: 17.9
# act_composite_2018: 17.7
# act_composite_2017: 17.8

# %% [markdown]
# The Composite score range from 1 to 36 and all datasets are within the score range.

# %%
# Check if there any duplicate rows for act_2019
act_2019.duplicated().sum()
# Out:
# 0

# %%
# Check if there any duplicate rows for act_2018
act_2018.duplicated().sum()
# Out:
# 1

# %%
# Check if there any duplicate rows for act_2017
act_2017.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is 1 duplicate row found for act_2018. This row will be dropped.

# %%
# Identify the row that is duplicated
print(act_2018[act_2018.duplicated()])
# Out:
#     state act_participation_2018  act_composite_2018
# 20  Maine                     7%                24.0

# %%
# Drop the duplicate row
act_2018.drop(act_2018.index[20], inplace = True)
act_2018.duplicated().sum()
# Out:
# 0

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   act_participation_2018  51 non-null     object
#  2   act_composite_2018      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
# Check which row for act_2019 is not the same as act_2018.
act_state_2019 = act_2019['state']
act_state_2018 = act_2018['state']
act_state_2019.apply(tuple,1).isin(act_state_2018.apply(tuple, 1))
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51    False
# Name: state, dtype: bool

# %%
act_2019.head(9)
# Out:
#                   state act_participation_2019  act_composite_2019
# 0               Alabama                   100%                18.9
# 1                Alaska                    38%                20.1
# 2               Arizona                    73%                19.0
# 3              Arkansas                   100%                19.3
# 4            California                    23%                22.6
# 5              Colorado                    27%                23.8
# 6           Connecticut                    22%                25.5
# 7              Delaware                    13%                24.1
# 8  District of Columbia                    32%                23.5

# %%
act_2018.head(9)
# Out:
#                   state act_participation_2018  act_composite_2018
# 0               Alabama                   100%                19.1
# 1                Alaska                    33%                20.8
# 2               Arizona                    66%                19.2
# 3              Arkansas                   100%                19.4
# 4            California                    27%                22.7
# 5              Colorado                    30%                23.9
# 6           Connecticut                    26%                25.6
# 7              Delaware                    17%                23.8
# 8  District of columbia                    32%                23.6

# %% [markdown]
# - The names for 'District of Columbia' differ in act_2019 and act_2018. We will keep the naming to be 'District of Columbia'.

# %%
# Rename to 'District of Columbia' for act_2018
act_2018.at[8, 'state'] = 'District of Columbia'
act_2018.head(9)
# Out:
#                   state act_participation_2018  act_composite_2018
# 0               Alabama                   100%                19.1
# 1                Alaska                    33%                20.8
# 2               Arizona                    66%                19.2
# 3              Arkansas                   100%                19.4
# 4            California                    27%                22.7
# 5              Colorado                    30%                23.9
# 6           Connecticut                    26%                25.6
# 7              Delaware                    17%                23.8
# 8  District of Columbia                    32%                23.6

# %%
act_2019.tail()
# Out:
#             state act_participation_2019  act_composite_2019
# 47     Washington                    24%                22.1
# 48  West Virginia                    49%                20.8
# 49      Wisconsin                   100%                20.3
# 50        Wyoming                   100%                19.8
# 51       National                    52%                20.7

# %%
act_2018.tail()
# Out:
#             state act_participation_2018  act_composite_2018
# 47       Virginia                    24%                23.9
# 48     Washington                    24%                22.2
# 49  West Virginia                    65%                20.3
# 50      Wisconsin                   100%                20.5
# 51        Wyoming                   100%                20.0

# %% [markdown]
# - National is not one of the states and is not found in act_2018 dataset. We will drop this row for act_2019.

# %%
# Drop the National row for act_2019
act_2019.drop(act_2019.index[51], inplace = True)
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   act_participation_2019  51 non-null     object
#  2   act_composite_2019      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
# Check which row for act_2017 is not the same as act_2018.
act_state_2017 = act_2017['state']
act_state_2017.apply(tuple,1).isin(act_state_2018.apply(tuple, 1))
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# Name: state, dtype: bool

# %%
act_2017.head()
# Out:
#       state act_participation_2017  act_composite_2017
# 0  National                    60%                21.0
# 1   Alabama                   100%                19.2
# 2    Alaska                    65%                19.8
# 3   Arizona                    62%                19.7
# 4  Arkansas                   100%                19.4

# %% [markdown]
# - Similarly, National is not of the states. We will drop this row as well.

# %%
# Drop the National row for act_2017
act_2017.drop(act_2017.index[0], inplace = True)
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   51 non-null     object
#  1   act_participation_2017  51 non-null     object
#  2   act_composite_2017      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
# Merge all sat and act datasets into 1 file
sat_act_dfs = [sat_2019, sat_2018, sat_2017, act_2019, act_2018, act_2017]
sat_act = reduce(lambda left,right: pd.merge(left, right, on='state', how='inner'), sat_act_dfs)
sat_act
# Out:
#                    state sat_participation_2019  ebrw_2019  math_2019  \
# 0                Alabama                     7%        583        560
# 1                 Alaska                    41%        556        541
# 2                Arizona                    31%        569        565
# 3               Arkansas                     6%        582        559
# 4             California                    63%        534        531
# 5               Colorado                   100%        518        506
# 6            Connecticut                   100%        529        516
# 7               Delaware                   100%        499        486
# 8   District of Columbia                    94%        495        480
# 9                Florida                   100%        516        483
# 10               Georgia                    71%        538        519
# 11                Hawaii                    54%        550        550
# ...

# %%
# Apply 'string_to_float' function to each of the participation rate columns and convert to % by multiplying with 100
for column in ['sat_participation_2019', 'sat_participation_2018', 'sat_participation_2017', 'act_participation_2019', \
               'act_participation_2018', 'act_participation_2017']:
    sat_act[column] = (sat_act[column].apply(string_to_float)) * 100
sat_act.head()
# Out:
#         state  sat_participation_2019  ebrw_2019  math_2019  sat_total_2019  \
# 0     Alabama                     7.0        583        560            1143
# 1      Alaska                    41.0        556        541            1097
# 2     Arizona                    31.0        569        565            1134
# 3    Arkansas                     6.0        582        559            1141
# 4  California                    63.0        534        531            1065
#
#    sat_participation_2018  ebrw_2018  math_2018  sat_total_2018  \
# 0                     6.0        595        571            1166
# 1                    43.0        562        544            1106
# 2                    29.0        577        572            1149
# 3                     5.0        592        576            1169
# 4                    60.0        540        536            1076
#
#    sat_participation_2017  ebrw_2017  math_2017  sat_total_2017  \
# ...

# %%
# Read the regions.csv and merge it with sat_act dataframe to include the regions information
regions = pd.read_csv('../data/regions.csv')
regions.head()

sat_act = pd.merge(sat_act, regions, on='state', how='inner')
sat_act.head()
# Out:
#         state  sat_participation_2019  ebrw_2019  math_2019  sat_total_2019  \
# 0     Alabama                     7.0        583        560            1143
# 1      Alaska                    41.0        556        541            1097
# 2     Arizona                    31.0        569        565            1134
# 3    Arkansas                     6.0        582        559            1141
# 4  California                    63.0        534        531            1065
#
#    sat_participation_2018  ebrw_2018  math_2018  sat_total_2018  \
# 0                     6.0        595        571            1166
# 1                    43.0        562        544            1106
# 2                    29.0        577        572            1149
# 3                     5.0        592        576            1169
# 4                    60.0        540        536            1076
#
#    sat_participation_2017  ebrw_2017  math_2017  sat_total_2017  \
# ...

# %%
# Create new columns to check the change in SAT participation rates from 2017 to 2019
sat_act['sat_diff_1819'] = sat_act['sat_participation_2019'] - sat_act['sat_participation_2018']
sat_act['sat_diff_1718'] = sat_act['sat_participation_2018'] - sat_act['sat_participation_2017']

# Create new columns to check the change in ACT participation rates from 2017 to 2019
sat_act['act_diff_1819'] = sat_act['act_participation_2019'] - sat_act['act_participation_2018']
sat_act['act_diff_1718'] = sat_act['act_participation_2018'] - sat_act['act_participation_2017']

# %%
# Create a function to average the participation rate
def average(df, column_name, column_list):
    df[column_name] = round((df[column_list].sum(axis=1) / len(column_list)),3)
    return df

# %%
# Create a new column for the average sat participation rates per state using the average function
average(sat_act, 'ave_sat_participation', ['sat_participation_2019', 'sat_participation_2018', 'sat_participation_2017',])
# Out:
#                    state  sat_participation_2019  ebrw_2019  math_2019  \
# 0                Alabama                     7.0        583        560
# 1                 Alaska                    41.0        556        541
# 2                Arizona                    31.0        569        565
# 3               Arkansas                     6.0        582        559
# 4             California                    63.0        534        531
# 5               Colorado                   100.0        518        506
# 6            Connecticut                   100.0        529        516
# 7               Delaware                   100.0        499        486
# 8   District of Columbia                    94.0        495        480
# 9                Florida                   100.0        516        483
# 10               Georgia                    71.0        538        519
# 11                Hawaii                    54.0        550        550
# ...

# %%
# Create a new column for the average act participation rates per state using the average function
average(sat_act, 'ave_act_participation', ['act_participation_2019', 'act_participation_2018', 'act_participation_2017',])
# Out:
#                    state  sat_participation_2019  ebrw_2019  math_2019  \
# 0                Alabama                     7.0        583        560
# 1                 Alaska                    41.0        556        541
# 2                Arizona                    31.0        569        565
# 3               Arkansas                     6.0        582        559
# 4             California                    63.0        534        531
# 5               Colorado                   100.0        518        506
# 6            Connecticut                   100.0        529        516
# 7               Delaware                   100.0        499        486
# 8   District of Columbia                    94.0        495        480
# 9                Florida                   100.0        516        483
# 10               Georgia                    71.0        538        519
# 11                Hawaii                    54.0        550        550
# ...

# %%
# Reorder the columns. Move 'region' column up
sat_act = sat_act.reindex(columns= ['state', 'region', 'sat_participation_2019', 'ebrw_2019', 'math_2019',
       'sat_total_2019', 'sat_participation_2018', 'ebrw_2018', 'math_2018', 
       'sat_total_2018', 'sat_participation_2017', 'ebrw_2017', 'math_2017',
       'sat_total_2017', 'act_participation_2019', 'act_composite_2019',
       'act_participation_2018', 'act_composite_2018',
       'act_participation_2017', 'act_composite_2017','sat_diff_1819', 'sat_diff_1718', 'act_diff_1819', 'act_diff_1718',
       'ave_sat_participation', 'ave_act_participation'])

sat_act.head()
# Out:
#         state region  sat_participation_2019  ebrw_2019  math_2019  \
# 0     Alabama  South                     7.0        583        560
# 1      Alaska   West                    41.0        556        541
# 2     Arizona   West                    31.0        569        565
# 3    Arkansas  South                     6.0        582        559
# 4  California   West                    63.0        534        531
#
#    sat_total_2019  sat_participation_2018  ebrw_2018  math_2018  \
# 0            1143                     6.0        595        571
# 1            1097                    43.0        562        544
# 2            1134                    29.0        577        572
# 3            1141                     5.0        592        576
# 4            1065                    60.0        540        536
#
#    sat_total_2018  ...  act_participation_2018  act_composite_2018  \
# 0            1166  ...                   100.0                19.1
# ...

# %%
# Export the final dataset to a csv file
sat_act.to_csv('../data/final_dataset.csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|*object*|sat_act.csv|US States|
# |region|*object*|sat_act.csv|US Regions|
# |sat_participation_2019|*float*|sat_act.csv|Percentage of SAT participation rate (2 decimal places) in 2019|
# |ebrw_2019|*integer*|sat_act.csv|Evidence based reading and writing score in 2019. Score range is 200 to 800|
# |math_2019|*integer*|sat_act.csv|Math score in 2019. Score range is 200 to 800|
# |sat_total_2019|*integer*|sat_act.csv|SAT Total score in 2019. Score range is 400 to 1600|
# |sat_participation_2018|*float*|sat_act.csv|Percentage of SAT participation rate (2 decimal places) in 2018|
# |ebrw_2018|*integer*|sat_act.csv|Evidence based reading and writing score in 2018. Score range is 200 to 800|
# |math_2018|*integer*|sat_act.csv|Math score in 2018. Score range is 200 to 800|
# |sat_total_2018|*integer*|sat_act.csv|SAT Total score in 2018. Score range is 400 to 1600|
# |sat_participation_2017|*float*|sat_act.csv|Percentage of SAT participation rate (2 decimal places) in 2017|
# |ebrw_2017|*integer*|sat_act.csv|Evidence based reading and writing score in 2017. Score range is 200 to 800|
# |math_2017|*integer*|sat_act.csv|Math score in 2017. Score range is 200 to 800|
# |sat_total_2017|*integer*|sat_act.csv|SAT Total score in 2017. Score range is 400 to 1600|
# |act_participation_2019|*float*|sat_act.csv|Percentage of ACT participation rate (2 decimal places) in 2019|
# |act_composite_2019|*float*|sat_act.csv|ACT Composite score in 2018. Score range is 1 to 36|
# |act_participation_2018|*float*|sat_act.csv|Percentage of ACT participation rate (2 decimal places) in 2018|
# |act_composite_2018|*float*|sat_act.csv|ACT Composite score in 2018. Score range is 1 to 36|
# |act_participation_2017|*float*|sat_act.csv|Percentage of ACT participation rate (2 decimal places) in 2017|
# |act_composite_2017|*float*|sat_act.csv|ACT Composite score in 2017. Score range is 1 to 36|
# |sat_diff_1819|*float*|sat_act.csv|Percentage difference in 2018 and 2019 SAT participation rate|
# |sat_diff_1718|*float*|sat_act.csv|Percentage difference in 2017 and 2018 SAT participation rate|
# |act_diff_1819|*float*|sat_act.csv|Percentage difference in 2018 and 2019 ACT participation rate|
# |act_diff_1718|*float*|sat_act.csv|Percentage difference in 2017 and 2018 ACT participation rate|
# |ave_sat_participation|*float*|sat_act.csv|Average SAT participation rate for 2017, 2018, and 2019 (in percentage)|
# |ave_act_participation|*float*|sat_act.csv|Average ACT participation rate for 2017, 2018, and 2019 (in percentage)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
sat_act.head()
# Out:
#         state region  sat_participation_2019  ebrw_2019  math_2019  \
# 0     Alabama  South                     7.0        583        560
# 1      Alaska   West                    41.0        556        541
# 2     Arizona   West                    31.0        569        565
# 3    Arkansas  South                     6.0        582        559
# 4  California   West                    63.0        534        531
#
#    sat_total_2019  sat_participation_2018  ebrw_2018  math_2018  \
# 0            1143                     6.0        595        571
# 1            1097                    43.0        562        544
# 2            1134                    29.0        577        572
# 3            1141                     5.0        592        576
# 4            1065                    60.0        540        536
#
#    sat_total_2018  ...  act_participation_2018  act_composite_2018  \
# 0            1166  ...                   100.0                19.1
# ...

# %%
# Apply the std_dev function to create a standard deviation dictionary
# Column name will be the key and std dev is the value
sd = {column: std_dev(sat_act[column]) for column in sat_act.columns if sat_act[column].dtypes != object}
sd
# Out:
# {'sat_participation_2019': 38.3658,
#  'ebrw_2019': 45.7924,
#  'math_2019': 50.7852,
#  'sat_total_2019': 96.2403,
#  'sat_participation_2018': 36.9466,
#  'ebrw_2018': 47.0346,
#  'math_2018': 47.3019,
#  'sat_total_2018': 93.2274,
#  'sat_participation_2017': 34.9291,
#  'ebrw_2017': 45.217,
#  'math_2017': 46.6571,
#  'sat_total_2017': 91.5835,
#  'act_participation_2019': 34.1758,
#  'act_composite_2019': 2.1729,
#  'act_participation_2018': 33.7017,
#  'act_composite_2018': 2.0908,
#  'act_participation_2017': 31.8242,
#  'act_composite_2017': 2.0008,
#  'sat_diff_1819': 11.6341,
#  'sat_diff_1718': 18.0917,
#  'act_diff_1819': 5.0114,
#  'act_diff_1718': 13.3245,
#  'ave_sat_participation': 35.4006,
#  'ave_act_participation': 32.546}

# %%
# Use describe to list a statistics summary and transpose the dataframe
sat_act.describe().transpose()
# Out:
#                         count         mean        std    min      25%  \
# sat_participation_2019   51.0    49.058824  38.747600    2.0     5.50
# ebrw_2019                51.0   560.803922  46.248035  483.0   527.50
# math_2019                51.0   552.196078  51.290553  460.0   511.50
# sat_total_2019           51.0  1113.078431  97.197910  943.0  1038.00
# sat_participation_2018   51.0    45.745098  37.314256    2.0     4.50
# ebrw_2018                51.0   563.686275  47.502627  480.0   534.50
# math_2018                51.0   556.235294  47.772623  480.0   522.50
# sat_total_2018           51.0  1120.019608  94.155083  977.0  1057.50
# sat_participation_2017   51.0    39.803922  35.276632    2.0     4.00
# ebrw_2017                51.0   569.117647  45.666901  482.0   533.50
# math_2017                51.0   556.882353  47.121395  468.0   523.50
# sat_total_2017           51.0  1126.098039  92.494812  950.0  1055.50
# ...

# %% [markdown]
# - There is a slight difference in the manually calculated standard deviation and the pandas data frame standard deviation as pandas standard deviation is normalized by N-1 by default.
# - The range for the participation rate is very large. This implies that some states participation rate is very low while some is very high.

# %%
# Check the 2019 top 10 states with SAT high participation rate and their corresponding ACT participation rate
sat_act[['state', 'region', 'sat_participation_2019', 'act_participation_2019']].sort_values(by='sat_participation_2019', \
                                                                                   ascending=False).head(10)
# Out:
#             state     region  sat_participation_2019  act_participation_2019
# 39   Rhode Island  Northeast                   100.0                    12.0
# 13       Illinois    Midwest                   100.0                    35.0
# 22       Michigan    Midwest                   100.0                    19.0
# 5        Colorado       West                   100.0                    27.0
# 6     Connecticut  Northeast                   100.0                    22.0
# 7        Delaware      South                   100.0                    13.0
# 9         Florida      South                   100.0                    54.0
# 12          Idaho       West                   100.0                    31.0
# 19          Maine  Northeast                    99.0                     6.0
# 48  West Virginia      South                    99.0                    49.0

# %%
# Check the 2018 top 10 states with SAT high participation rate and their corresponding ACT participation rate
sat_act[['state', 'region', 'sat_participation_2018', 'act_participation_2018']].sort_values(by='sat_participation_2018', \
                                                                                   ascending=False).head(10)
# Out:
#                    state     region  sat_participation_2018  \
# 5               Colorado       West                   100.0
# 6            Connecticut  Northeast                   100.0
# 7               Delaware      South                   100.0
# 22              Michigan    Midwest                   100.0
# 12                 Idaho       West                   100.0
# 19                 Maine  Northeast                    99.0
# 13              Illinois    Midwest                    99.0
# 39          Rhode Island  Northeast                    97.0
# 29         New Hampshire  Northeast                    96.0
# 8   District of Columbia      South                    92.0
#
#     act_participation_2018
# 5                     30.0
# 6                     26.0
# 7                     17.0
# 22                    22.0
# 12                    36.0
# 19                     7.0
# 13                    43.0
# 39                    15.0
# 29                    16.0
# ...

# %%
# Check the 2017 top 10 states with SAT high participation rate and their corresponding ACT participation rate
sat_act[['state', 'region', 'sat_participation_2017', 'act_participation_2017']].sort_values(by='sat_participation_2017', \
                                                                                   ascending=False).head(10)
# Out:
#                    state     region  sat_participation_2017  \
# 8   District of Columbia      South                   100.0
# 22              Michigan    Midwest                   100.0
# 6            Connecticut  Northeast                   100.0
# 7               Delaware      South                   100.0
# 29         New Hampshire  Northeast                    96.0
# 19                 Maine  Northeast                    95.0
# 12                 Idaho       West                    93.0
# 9                Florida      South                    83.0
# 21         Massachusetts  Northeast                    76.0
# 39          Rhode Island  Northeast                    71.0
#
#     act_participation_2017
# 8                     32.0
# 22                    29.0
# 6                     31.0
# 7                     18.0
# 29                    18.0
# 19                     8.0
# 12                    38.0
# 9                     73.0
# 21                    29.0
# ...

# %%
# Check the 2019 top 10 states with low SAT participation rate and their corresponding ACT participation rate
sat_act[['state', 'region', 'sat_participation_2019', 'act_participation_2019']].sort_values(by='sat_participation_2019').head(10)
# Out:
#            state   region  sat_participation_2019  act_participation_2019
# 34  North Dakota  Midwest                     2.0                    96.0
# 50       Wyoming     West                     3.0                   100.0
# 41  South Dakota  Midwest                     3.0                    75.0
# 27      Nebraska  Midwest                     3.0                   100.0
# 49     Wisconsin  Midwest                     3.0                   100.0
# 24   Mississippi    South                     3.0                   100.0
# 15          Iowa  Midwest                     3.0                    66.0
# 44          Utah     West                     4.0                   100.0
# 23     Minnesota  Midwest                     4.0                    95.0
# 17      Kentucky    South                     4.0                   100.0

# %%
# Check the 2018 top 10 states with low SAT participation rate and their corresponding ACT participation rate
sat_act[['state', 'region', 'sat_participation_2018', 'act_participation_2018']].sort_values(by='sat_participation_2018').head(10)
# Out:
#            state   region  sat_participation_2018  act_participation_2018
# 34  North Dakota  Midwest                     2.0                    98.0
# 50       Wyoming     West                     3.0                   100.0
# 41  South Dakota  Midwest                     3.0                    77.0
# 27      Nebraska  Midwest                     3.0                   100.0
# 49     Wisconsin  Midwest                     3.0                   100.0
# 24   Mississippi    South                     3.0                   100.0
# 15          Iowa  Midwest                     3.0                    68.0
# 44          Utah     West                     4.0                   100.0
# 23     Minnesota  Midwest                     4.0                    99.0
# 18     Louisiana    South                     4.0                   100.0

# %%
# Check the 2017 top 10 states with low SAT participation rate and their corresponding ACT participation rate
sat_act[['state', 'region', 'sat_participation_2017', 'act_participation_2017']].sort_values(by='sat_participation_2017').head(10)
# Out:
#            state   region  sat_participation_2017  act_participation_2017
# 34  North Dakota  Midwest                     2.0                    98.0
# 24   Mississippi    South                     2.0                   100.0
# 15          Iowa  Midwest                     2.0                    67.0
# 25      Missouri  Midwest                     3.0                   100.0
# 44          Utah     West                     3.0                   100.0
# 41  South Dakota  Midwest                     3.0                    80.0
# 27      Nebraska  Midwest                     3.0                    84.0
# 49     Wisconsin  Midwest                     3.0                   100.0
# 23     Minnesota  Midwest                     3.0                   100.0
# 50       Wyoming     West                     3.0                   100.0

# %%
# List the states with 100% SAT participation rate in 2019
sat_act[['state', 'region', 'sat_participation_2019', 'act_participation_2019',]][sat_act["sat_participation_2019"] == 100]
# Out:
#            state     region  sat_participation_2019  act_participation_2019
# 5       Colorado       West                   100.0                    27.0
# 6    Connecticut  Northeast                   100.0                    22.0
# 7       Delaware      South                   100.0                    13.0
# 9        Florida      South                   100.0                    54.0
# 12         Idaho       West                   100.0                    31.0
# 13      Illinois    Midwest                   100.0                    35.0
# 22      Michigan    Midwest                   100.0                    19.0
# 39  Rhode Island  Northeast                   100.0                    12.0

# %%
# List the states with 100% SAT participation rate in 2018
sat_act[['state', 'region', 'sat_participation_2018', 'act_participation_2018',]][sat_act["sat_participation_2018"] == 100]
# Out:
#           state     region  sat_participation_2018  act_participation_2018
# 5      Colorado       West                   100.0                    30.0
# 6   Connecticut  Northeast                   100.0                    26.0
# 7      Delaware      South                   100.0                    17.0
# 12        Idaho       West                   100.0                    36.0
# 22     Michigan    Midwest                   100.0                    22.0

# %%
# List the states with 100% SAT participation rate in 2017
sat_act[['state', 'region', 'sat_participation_2017', 'act_participation_2017',]][sat_act["sat_participation_2017"] == 100]
# Out:
#                    state     region  sat_participation_2017  \
# 6            Connecticut  Northeast                   100.0
# 7               Delaware      South                   100.0
# 8   District of Columbia      South                   100.0
# 22              Michigan    Midwest                   100.0
#
#     act_participation_2017
# 6                     31.0
# 7                     18.0
# 8                     32.0
# 22                    29.0

# %%
# Count the number of states with 100% SAT participation rate in 2019
print(f"Number of states with 100% SAT participation rate in 2019: {sat_act[sat_act['sat_participation_2019'] == 100]['state'].count()}")
# Out:
# Number of states with 100% SAT participation rate in 2019: 8

# %%
# Count the number of states with 100% SAT participation rate in 2018
print(f"Number of states with 100% SAT participation rate in 2018: {sat_act[sat_act['sat_participation_2018'] == 100]['state'].count()}")
# Out:
# Number of states with 100% SAT participation rate in 2018: 5

# %%
# Count the number of states with 100% SAT participation rate in 2017
print(f"Number of states with 100% SAT participation rate in 2017: {sat_act[sat_act['sat_participation_2017'] == 100]['state'].count()}")
# Out:
# Number of states with 100% SAT participation rate in 2017: 4

# %% [markdown]
# **Analysis 1:**
# - Connecticut, Delaware, and Michigan have been consistently having 100% SAT participation rate for 2017 to 2019. These 3 states has the requirement for students to take SAT.
# - States with high SAT participation rate have a lower ACT participation rate and vice versa.
# - States with low SAT participation rate (<5%) have a higher ACT participation rate (>65%).
# - There is an increase in the number of states that has 100% SAT participation rate since 2018 with Midwest region showing a better performance in 2019. This can be attributed due to growth of SAT School Day, a program where students take the SAT in their own school on a weekday, rather than taking it on a Saturday in a different school than the one they attend and benefits of the fee wavier ([source](https://www.edweek.org/teaching-learning/sat-scores-rise-as-number-of-test-takers-tops-2-million/2018/10)).

# %%
# Check the 2019 top 10 states with high ACT participation rate and their corresponding SAT participation rate
sat_act[['state', 'region', 'act_participation_2019', 'sat_participation_2019']].sort_values(by='act_participation_2019', \
                                                                                   ascending=False).head(10)
# Out:
#              state   region  act_participation_2019  sat_participation_2019
# 0          Alabama    South                   100.0                     7.0
# 17        Kentucky    South                   100.0                     4.0
# 49       Wisconsin  Midwest                   100.0                     3.0
# 44            Utah     West                   100.0                     4.0
# 42       Tennessee    South                   100.0                     7.0
# 36        Oklahoma    South                   100.0                    22.0
# 35            Ohio  Midwest                   100.0                    19.0
# 33  North Carolina    South                   100.0                    51.0
# 28          Nevada     West                   100.0                    20.0
# 27        Nebraska  Midwest                   100.0                     3.0

# %%
# Check the 2018 top 10 states with high ACT participation rate and their corresponding SAT participation rate
sat_act[['state', 'region', 'act_participation_2018', 'sat_participation_2018']].sort_values(by='act_participation_2018', \
                                                                                   ascending=False).head(10)
# Out:
#              state   region  act_participation_2018  sat_participation_2018
# 0          Alabama    South                   100.0                     6.0
# 17        Kentucky    South                   100.0                     4.0
# 49       Wisconsin  Midwest                   100.0                     3.0
# 44            Utah     West                   100.0                     4.0
# 42       Tennessee    South                   100.0                     6.0
# 40  South Carolina    South                   100.0                    55.0
# 36        Oklahoma    South                   100.0                     8.0
# 35            Ohio  Midwest                   100.0                    18.0
# 33  North Carolina    South                   100.0                    52.0
# 28          Nevada     West                   100.0                    23.0

# %%
# Check the 2017 top 10 states with high ACT participation rate and their corresponding SAT participation rate
sat_act[['state', 'region', 'act_participation_2017', 'sat_participation_2017']].sort_values(by='act_participation_2017', \
                                                                                   ascending=False).head(10)
# Out:
#              state   region  act_participation_2017  sat_participation_2017
# 0          Alabama    South                   100.0                     5.0
# 17        Kentucky    South                   100.0                     4.0
# 49       Wisconsin  Midwest                   100.0                     3.0
# 44            Utah     West                   100.0                     3.0
# 42       Tennessee    South                   100.0                     5.0
# 40  South Carolina    South                   100.0                    50.0
# 36        Oklahoma    South                   100.0                     7.0
# 33  North Carolina    South                   100.0                    49.0
# 28          Nevada     West                   100.0                    26.0
# 26         Montana     West                   100.0                    10.0

# %%
# Check the 2019 top 10 states with low ACT participation rate and their corresponding SAT participation rate
sat_act[['state', 'region', 'act_participation_2019', 'sat_participation_2019']].sort_values(by='act_participation_2019').head(10)
# Out:
#             state     region  act_participation_2019  sat_participation_2019
# 19          Maine  Northeast                     6.0                    99.0
# 39   Rhode Island  Northeast                    12.0                   100.0
# 7        Delaware      South                    13.0                   100.0
# 29  New Hampshire  Northeast                    14.0                    95.0
# 38   Pennsylvania  Northeast                    17.0                    70.0
# 22       Michigan    Midwest                    19.0                   100.0
# 45        Vermont  Northeast                    20.0                    66.0
# 46       Virginia      South                    21.0                    68.0
# 21  Massachusetts  Northeast                    21.0                    81.0
# 32       New York  Northeast                    22.0                    79.0

# %%
# Check the 2018 top 10 states with low ACT participation rate and their corresponding SAT participation rate
sat_act[['state', 'region', 'act_participation_2018', 'sat_participation_2018']].sort_values(by='act_participation_2018').head(10)
# Out:
#             state     region  act_participation_2018  sat_participation_2018
# 19          Maine  Northeast                     7.0                    99.0
# 39   Rhode Island  Northeast                    15.0                    97.0
# 29  New Hampshire  Northeast                    16.0                    96.0
# 7        Delaware      South                    17.0                   100.0
# 38   Pennsylvania  Northeast                    20.0                    70.0
# 22       Michigan    Midwest                    22.0                   100.0
# 47     Washington       West                    24.0                    69.0
# 45        Vermont  Northeast                    24.0                    64.0
# 46       Virginia      South                    24.0                    68.0
# 21  Massachusetts  Northeast                    25.0                    80.0

# %%
# Check the 2017 top 10 states with low ACT participation rate and their corresponding SAT participation rate
sat_act[['state', 'region', 'act_participation_2017', 'sat_participation_2017']].sort_values(by='act_participation_2017').head(10)
# Out:
#             state     region  act_participation_2017  sat_participation_2017
# 19          Maine  Northeast                     8.0                    95.0
# 29  New Hampshire  Northeast                    18.0                    96.0
# 7        Delaware      South                    18.0                   100.0
# 39   Rhode Island  Northeast                    21.0                    71.0
# 38   Pennsylvania  Northeast                    23.0                    65.0
# 20       Maryland      South                    28.0                    69.0
# 45        Vermont  Northeast                    29.0                    60.0
# 21  Massachusetts  Northeast                    29.0                    76.0
# 22       Michigan    Midwest                    29.0                   100.0
# 46       Virginia      South                    29.0                    65.0

# %%
# List the states with 100% ACT participation rate in 2019
sat_act[['state', 'region', 'act_participation_2019', 'sat_participation_2019']][sat_act["act_participation_2019"] == 100]
# Out:
#              state   region  act_participation_2019  sat_participation_2019
# 0          Alabama    South                   100.0                     7.0
# 3         Arkansas    South                   100.0                     6.0
# 17        Kentucky    South                   100.0                     4.0
# 18       Louisiana    South                   100.0                     5.0
# 24     Mississippi    South                   100.0                     3.0
# 26         Montana     West                   100.0                     9.0
# 27        Nebraska  Midwest                   100.0                     3.0
# 28          Nevada     West                   100.0                    20.0
# 33  North Carolina    South                   100.0                    51.0
# 35            Ohio  Midwest                   100.0                    19.0
# 36        Oklahoma    South                   100.0                    22.0
# ...

# %%
# List the states with 100% ACT participation rate in 2018
sat_act[['state', 'region', 'act_participation_2018', 'sat_participation_2018']][sat_act["act_participation_2018"] == 100]
# Out:
#              state   region  act_participation_2018  sat_participation_2018
# 0          Alabama    South                   100.0                     6.0
# 3         Arkansas    South                   100.0                     5.0
# 17        Kentucky    South                   100.0                     4.0
# 18       Louisiana    South                   100.0                     4.0
# 24     Mississippi    South                   100.0                     3.0
# 25        Missouri  Midwest                   100.0                     4.0
# 26         Montana     West                   100.0                    10.0
# 27        Nebraska  Midwest                   100.0                     3.0
# 28          Nevada     West                   100.0                    23.0
# 33  North Carolina    South                   100.0                    52.0
# 35            Ohio  Midwest                   100.0                    18.0
# ...

# %%
# List the states with 100% ACT participation rate in 2017
sat_act[['state', 'region', 'act_participation_2017', 'sat_participation_2017']][sat_act["act_participation_2017"] == 100]
# Out:
#              state   region  act_participation_2017  sat_participation_2017
# 0          Alabama    South                   100.0                     5.0
# 3         Arkansas    South                   100.0                     3.0
# 5         Colorado     West                   100.0                    11.0
# 17        Kentucky    South                   100.0                     4.0
# 18       Louisiana    South                   100.0                     4.0
# 23       Minnesota  Midwest                   100.0                     3.0
# 24     Mississippi    South                   100.0                     2.0
# 25        Missouri  Midwest                   100.0                     3.0
# 26         Montana     West                   100.0                    10.0
# 28          Nevada     West                   100.0                    26.0
# 33  North Carolina    South                   100.0                    49.0
# ...

# %%
# Count the number of states with 100% ACT participation rate in 2019
print(f"Number of states with 100% ACT participation rate in 2019: {sat_act[sat_act['act_participation_2019'] == 100]['state'].count()}")
# Out:
# Number of states with 100% ACT participation rate in 2019: 15

# %%
# Count the number of states with 100% ACT participation rate in 2018
print(f"Number of states with 100% ACT participation rate in 2018: {sat_act[sat_act['act_participation_2018'] == 100]['state'].count()}")
# Out:
# Number of states with 100% ACT participation rate in 2018: 17

# %%
# Count the number of states with 100% ACT participation rate in 2017
print(f"Number of states with 100% ACT participation rate in 2017: {sat_act[sat_act['act_participation_2017'] == 100]['state'].count()}")
# Out:
# Number of states with 100% ACT participation rate in 2017: 17

# %% [markdown]
# **Analysis 2:**
# - Alabama, Arkansas, Kentucky, Louisiana, Mississippi, Montana, Nevada, North Carolina, Oklahoma, Tennessee, Wisconsin and Wyoming have 100% participation rate from 2017 to 2019. All except Arkansas have the requirement to take ACT or chose either ACT or SAT.
# - States with high ACT participation rate have a lower SAT participation rate and vice versa.
# - In general, ACT participation rate is observed to better than SAT participation rate. There are more states with 100% participation rate for ACT. ACT seems to be a preferred choice as more states made it mandatory and provide for the students. South and Midwest regions seem to perform better than the other 3 regions.

# %%
# List states with >50% participation rate for both SAT and ACT tests in 2019
sat_act[['state', 'region', 'sat_participation_2019', 'act_participation_2019']][(sat_act['sat_participation_2019'] > 50) & \
                                                                       (sat_act['act_participation_2019'] > 50)]
# Out:
#              state region  sat_participation_2019  act_participation_2019
# 9          Florida  South                   100.0                    54.0
# 11          Hawaii   West                    54.0                    80.0
# 33  North Carolina  South                    51.0                   100.0
# 40  South Carolina  South                    68.0                    78.0

# %%
# List states with >50% participation rate for both SAT and ACT tests in 2018
sat_act[['state', 'region', 'sat_participation_2018', 'act_participation_2018']][(sat_act['sat_participation_2018'] > 50) & \
                                                                       (sat_act['act_participation_2018'] > 50)]
# Out:
#              state region  sat_participation_2018  act_participation_2018
# 9          Florida  South                    56.0                    66.0
# 10         Georgia  South                    70.0                    53.0
# 11          Hawaii   West                    56.0                    89.0
# 33  North Carolina  South                    52.0                   100.0
# 40  South Carolina  South                    55.0                   100.0

# %%
# List states with >50% participation rate for both SAT and ACT tests in 2017
sat_act[['state', 'region', 'sat_participation_2017', 'act_participation_2017']][(sat_act['sat_participation_2017'] > 50) & \
                                                                       (sat_act['act_participation_2017'] > 50)]
# Out:
#       state region  sat_participation_2017  act_participation_2017
# 9   Florida  South                    83.0                    73.0
# 10  Georgia  South                    61.0                    55.0
# 11   Hawaii   West                    55.0                    90.0

# %% [markdown]
# **Analysis 3:**
# - Florida, Hawaii, North Carolina and South Carolina have both SAT and ACT participation rate > 50% in 2019.
# - It is interesting to note that North Carolina has ~50% participation rate for ACT even though it has 100% participation rate for SAT. This means a substantial number of students took both tests for this state.
# - Florida, Georgia, Hawaii, North Carolina and South Carolina have both SAT and ACT participation rate > 50% in 2018.
# - Florida, Georgia and Hawaii have both SAT and ACT participation rate > 50% in 2017.
# - States in the South region seems to have better participation rate for both tests.
# - Florida and Georgia have been consistent in participating both the SAT and ACT tests.
# - Students in the South region have higher tendency to take both tests.

# %%
# Check the biggest increase in 2019 SAT participation
sat_act[['state', 'region', 'sat_diff_1819', 'sat_participation_2019', 'sat_participation_2018']].sort_values(by='sat_diff_1819', \
                                                                                                    ascending=False).head(10)
# Out:
#              state     region  sat_diff_1819  sat_participation_2019  \
# 48   West Virginia      South           71.0                    99.0
# 9          Florida      South           44.0                   100.0
# 36        Oklahoma      South           14.0                    22.0
# 40  South Carolina      South           13.0                    68.0
# 20        Maryland      South            6.0                    82.0
# 39    Rhode Island  Northeast            3.0                   100.0
# 37          Oregon       West            3.0                    51.0
# 4       California       West            3.0                    63.0
# 14         Indiana    Midwest            3.0                    66.0
# 2          Arizona       West            2.0                    31.0
#
#     sat_participation_2018
# 48                    28.0
# 9                     56.0
# 36                     8.0
# 40                    55.0
# 20                    76.0
# 39                    97.0
# ...

# %%
# Check the biggest increase in 2018 SAT participation
sat_act[['state', 'region', 'sat_diff_1718', 'sat_participation_2018', 'sat_participation_2017']].sort_values(by='sat_diff_1718', \
                                                                                                    ascending=False).head(10)
# Out:
#             state     region  sat_diff_1718  sat_participation_2018  \
# 13       Illinois    Midwest           90.0                    99.0
# 5        Colorado       West           89.0                   100.0
# 39   Rhode Island  Northeast           26.0                    97.0
# 48  West Virginia      South           14.0                    28.0
# 32       New York  Northeast           12.0                    79.0
# 30     New Jersey  Northeast           12.0                    82.0
# 10        Georgia      South            9.0                    70.0
# 4      California       West            7.0                    60.0
# 20       Maryland      South            7.0                    76.0
# 12          Idaho       West            7.0                   100.0
#
#     sat_participation_2017
# 13                     9.0
# 5                     11.0
# 39                    71.0
# 48                    14.0
# 32                    67.0
# 30                    70.0
# ...

# %%
# Check the biggest decline in 2019 SAT participation
sat_act[['state', 'region', 'sat_diff_1819', 'sat_participation_2019', 'sat_participation_2018']].sort_values(by='sat_diff_1819').head(10)
# Out:
#              state     region  sat_diff_1819  sat_participation_2019  \
# 28          Nevada       West           -3.0                    20.0
# 11          Hawaii       West           -2.0                    54.0
# 1           Alaska       West           -2.0                    41.0
# 26         Montana       West           -1.0                     9.0
# 33  North Carolina      South           -1.0                    51.0
# 29   New Hampshire  Northeast           -1.0                    95.0
# 25        Missouri    Midwest            0.0                     4.0
# 24     Mississippi      South            0.0                     3.0
# 49       Wisconsin    Midwest            0.0                     3.0
# 27        Nebraska    Midwest            0.0                     3.0
#
#     sat_participation_2018
# 28                    23.0
# 11                    56.0
# 1                     43.0
# 26                    10.0
# 33                    52.0
# 29                    96.0
# ...

# %%
# Check the biggest decline in 2018 SAT participation
sat_act[['state', 'region', 'sat_diff_1718', 'sat_participation_2018', 'sat_participation_2017']].sort_values(by='sat_diff_1718').head(10)
# Out:
#                    state   region  sat_diff_1718  sat_participation_2018  \
# 9                Florida    South          -27.0                    56.0
# 8   District of Columbia    South           -8.0                    92.0
# 28                Nevada     West           -3.0                    23.0
# 2                Arizona     West           -1.0                    29.0
# 50               Wyoming     West            0.0                     3.0
# 49             Wisconsin  Midwest            0.0                     3.0
# 18             Louisiana    South            0.0                     4.0
# 17              Kentucky    South            0.0                     4.0
# 16                Kansas  Midwest            0.0                     4.0
# 26               Montana     West            0.0                    10.0
#
#     sat_participation_2017
# 9                     83.0
# 8                    100.0
# 28                    26.0
# 2                     30.0
# ...

# %%
# List states with 100% SAT participation in 2018 has a change in the participation rate in 2019
sat_act[['state', 'region', 'sat_diff_1819', 'sat_participation_2019', 'sat_participation_2018']][(sat_act['sat_participation_2018']\
                                                                                         == 100) & (sat_act['sat_diff_1819'] != 0)]
# Out:
# Empty DataFrame
# Columns: [state, region, sat_diff_1819, sat_participation_2019, sat_participation_2018]
# Index: []

# %%
# List states with 100% SAT participation in 2017 has a change in the participation rate in 2018
sat_act[['state', 'region', 'sat_diff_1718', 'sat_participation_2018', 'sat_participation_2017']][(sat_act['sat_participation_2017']\
                                                                                         == 100) & (sat_act['sat_diff_1718'] != 0)]
# Out:
#                   state region  sat_diff_1718  sat_participation_2018  \
# 8  District of Columbia  South           -8.0                    92.0
#
#    sat_participation_2017
# 8                   100.0

# %% [markdown]
# **Analysis 4:**
# - West Virginia has the largest SAT participation rate increase (71%), followed by Florida (44%) in 2019.
# - Illinois has the largest SAT participation rate increase (90%), followed by Colorado (89%) in 2018.
# - The increase in the participation rate can be attributed to the SAT School Day cited in Analysis 1.
# - Florida was observed to have the biggest decline (-27%) in the SAT participation rate in 2018.
# - There is a SAT participation rate drop from 100% to 92% for District of Columbia.
# - SAT has gained popularity in South region.
# - The decline for SAT participation is not significant other than Florida, although a few states in the West region has dropped its participation rate.

# %%
# Check the biggest increase in 2019 ACT participation
sat_act[['state', 'region', 'act_diff_1819', 'act_participation_2019', 'act_participation_2018']].sort_values(by='act_diff_1819', \
                                                                                                    ascending=False).head(10)
# Out:
#              state   region  act_diff_1819  act_participation_2019  \
# 2          Arizona     West            7.0                    73.0
# 1           Alaska     West            5.0                    38.0
# 16          Kansas  Midwest            1.0                    72.0
# 35            Ohio  Midwest            0.0                   100.0
# 24     Mississippi    South            0.0                   100.0
# 26         Montana     West            0.0                   100.0
# 27        Nebraska  Midwest            0.0                   100.0
# 28          Nevada     West            0.0                   100.0
# 33  North Carolina    South            0.0                   100.0
# 0          Alabama    South            0.0                   100.0
#
#     act_participation_2018
# 2                     66.0
# 1                     33.0
# 16                    71.0
# 35                   100.0
# 24                   100.0
# 26                   100.0
# 27                   100.0
# ...

# %%
# Check the biggest increase in 2018 ACT participation
sat_act[['state', 'region', 'act_diff_1718', 'act_participation_2018', 'act_participation_2017']].sort_values(by='act_diff_1718', \
                                                                                                    ascending=False).head(10)
# Out:
#              state   region  act_diff_1718  act_participation_2018  \
# 35            Ohio  Midwest           25.0                   100.0
# 27        Nebraska  Midwest           16.0                   100.0
# 2          Arizona     West            4.0                    66.0
# 20        Maryland    South            3.0                    31.0
# 37          Oregon     West            2.0                    42.0
# 15            Iowa  Midwest            1.0                    68.0
# 31      New Mexico     West            1.0                    67.0
# 0          Alabama    South            0.0                   100.0
# 33  North Carolina    South            0.0                   100.0
# 26         Montana     West            0.0                   100.0
#
#     act_participation_2017
# 35                    75.0
# 27                    84.0
# 2                     62.0
# 20                    28.0
# 37                    40.0
# 15                    67.0
# 31                    66.0
# ...

# %%
# Check the biggest decline in 2019 ACT participation
sat_act[['state', 'region', 'act_diff_1819', 'act_participation_2019', 'act_participation_2018']].sort_values(by='act_diff_1819').head(10)
# Out:
#              state     region  act_diff_1819  act_participation_2019  \
# 40  South Carolina      South          -22.0                    78.0
# 25        Missouri    Midwest          -18.0                    82.0
# 48   West Virginia      South          -16.0                    49.0
# 9          Florida      South          -12.0                    54.0
# 11          Hawaii       West           -9.0                    80.0
# 13        Illinois    Midwest           -8.0                    35.0
# 30      New Jersey  Northeast           -6.0                    25.0
# 43           Texas      South           -6.0                    39.0
# 32        New York  Northeast           -5.0                    22.0
# 12           Idaho       West           -5.0                    31.0
#
#     act_participation_2018
# 40                   100.0
# 25                   100.0
# 48                    65.0
# 9                     66.0
# 11                    89.0
# 13                    43.0
# ...

# %%
# Check the biggest decline in 2018 ACT participation
sat_act[['state', 'region', 'act_diff_1718', 'act_participation_2018', 'act_participation_2017']].sort_values(by='act_diff_1718').head(10)
# Out:
#            state     region  act_diff_1718  act_participation_2018  \
# 5       Colorado       West          -70.0                    30.0
# 13      Illinois    Midwest          -50.0                    43.0
# 1         Alaska       West          -32.0                    33.0
# 9        Florida      South           -7.0                    66.0
# 22      Michigan    Midwest           -7.0                    22.0
# 39  Rhode Island  Northeast           -6.0                    15.0
# 6    Connecticut  Northeast           -5.0                    26.0
# 47    Washington       West           -5.0                    24.0
# 45       Vermont  Northeast           -5.0                    24.0
# 46      Virginia      South           -5.0                    24.0
#
#     act_participation_2017
# 5                    100.0
# 13                    93.0
# 1                     65.0
# 9                     73.0
# 22                    29.0
# 39                    21.0
# 6                     31.0
# ...

# %%
# List states with 100% ACT participation in 2018 has a change in the participation rate in 2019
sat_act[['state', 'region', 'act_diff_1819', 'act_participation_2019', 'act_participation_2018']][(sat_act['act_participation_2018']\
                                                                                         == 100) & (sat_act['act_diff_1819'] != 0)]
# Out:
#              state   region  act_diff_1819  act_participation_2019  \
# 25        Missouri  Midwest          -18.0                    82.0
# 40  South Carolina    South          -22.0                    78.0
#
#     act_participation_2018
# 25                   100.0
# 40                   100.0

# %%
# List states with 100% ACT participation in 2017 has a change in the participation rate in 2018
sat_act[['state', 'region', 'act_diff_1718', 'act_participation_2018', 'act_participation_2017']][(sat_act['act_participation_2017']\
                                                                                         == 100) & (sat_act['act_diff_1718'] != 0)]
# Out:
#         state   region  act_diff_1718  act_participation_2018  \
# 5    Colorado     West          -70.0                    30.0
# 23  Minnesota  Midwest           -1.0                    99.0
#
#     act_participation_2017
# 5                    100.0
# 23                   100.0

# %% [markdown]
# **Analysis 5:**
# - Arizona has the largest ACT participation rate increase (7%), followed by Alaska (5%) in 2019.
# - Ohio has the largest ACT participation rate increase (25%), followed by Nebraska (16%) in 2018.
# - South Carolina was observed to have the biggest decline (-22%) in the ACT participation rate in 2019.
# - Colorado was observed to have the biggest decline (-70%), followed by Illinois (-50%) in the ACT participation rate in 2018.
# - There is a ACT participation rate drop from 100% to 78% for South Carolina and from 100% to 82% for Missouri in 2019.
# - There is a ACT participation rate drop from 100% to 30% for Colorado in 2019. The decline for Colorado ACT participation since 2018 is because the state has made SAT compulsory.

# %%
# Check SAT average participation rate by regions
sat_participation_by_region = sat_act.groupby('region')['ave_sat_participation'].agg(['count', 'mean', 'median'])
sat_participation_by_region.reset_index(inplace=True)
sat_participation_by_region
# Out:
#       region  count       mean  median
# 0    Midwest     12  22.888917   3.667
# 1  Northeast      9  82.925889  79.000
# 2      South     17  43.862765  50.667
# 3       West     13  40.128308  40.667

# %%
# Check ACT average participation rate by regions
act_participation_by_region = sat_act.groupby('region')['ave_act_participation'].agg(['count', 'mean', 'median'])
act_participation_by_region.reset_index(inplace=True)
act_participation_by_region
# Out:
#       region  count       mean  median
# 0    Midwest     12  75.361083  84.500
# 1  Northeast      9  21.259222  24.333
# 2      South     17  71.470588  92.667
# 3       West     13  65.025538  65.333

# %% [markdown]
# **Analysis 6:**
# - Midwest region fares better in ACT test while Northeast region fares better in SAT test.
# - South region fares better in ACT test but it's SAT participation rate of 43.86% is relatively not too bad.
# - West region fares better in ACT test also.

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
sat_act.describe()
# Out:
#        sat_participation_2019   ebrw_2019   math_2019  sat_total_2019  \
# count               51.000000   51.000000   51.000000       51.000000
# mean                49.058824  560.803922  552.196078     1113.078431
# std                 38.747600   46.248035   51.290553       97.197910
# min                  2.000000  483.000000  460.000000      943.000000
# 25%                  5.500000  527.500000  511.500000     1038.000000
# 50%                 54.000000  550.000000  546.000000     1097.000000
# 75%                 82.000000  612.000000  599.000000     1210.000000
# max                100.000000  636.000000  648.000000     1284.000000
#
#        sat_participation_2018   ebrw_2018   math_2018  sat_total_2018  \
# count               51.000000   51.000000   51.000000       51.000000
# mean                45.745098  563.686275  556.235294     1120.019608
# std                 37.314256   47.502627   47.772623       94.155083
# ...

# %%
# generate a full correlation matrix for all columns in sat_act
sat_act.corr()
# Out:
#                         sat_participation_2019  ebrw_2019  math_2019  \
# sat_participation_2019                1.000000  -0.873453  -0.845841
# ebrw_2019                            -0.873453   1.000000   0.986026
# math_2019                            -0.845841   0.986026   1.000000
# sat_total_2019                       -0.861786   0.996134   0.996825
# sat_participation_2018                0.952967  -0.795342  -0.751634
# ebrw_2018                            -0.789814   0.865572   0.831921
# math_2018                            -0.835846   0.940199   0.933717
# sat_total_2018                       -0.822584   0.913307   0.893029
# sat_participation_2017                0.844118  -0.700507  -0.673190
# ebrw_2017                            -0.838622   0.898352   0.876606
# math_2017                            -0.829083   0.901134   0.902478
# sat_total_2017                       -0.836916   0.903106   0.892973
# act_participation_2019               -0.865435   0.688592   0.643101
# ...

# %%
# Create a heatmap of correlation coefficients
plt.figure(figsize=(16,14))
cmap = sns.diverging_palette(0, 230, 90, 60, as_cmap=True)
sns.heatmap(sat_act.corr(), cmap = cmap, linewidths=3, fmt='.2f', annot=True, annot_kws={'fontsize':11})

plt.title('SAT and ACT Correlation Matrix from 2017 to 2019', loc='center', fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'SAT and ACT Correlation Matrix from 2017 to 2019')

# %% [markdown]
# **Interpretation 1:**
# - The SAT participation rate has a strong negative correlation with its total and subject scores. This is also observed for the ACT participation rate. This means states with higher participation rate tend to have a lower score than state with lower participation rate.
# - Participation rate for a specific year is strongly correlated to previous years. This means if participation rate for 2017 is high, the participation rate for 2018 and 2019 will be high.
# - The test scores for 2019 has a strong positive correlation with the same test score in 2018 and 2017 respectively. This means states that done well in previous year is likely to do well in current year.
# - The subject scores for SAT has a strong positive correlation with each other. This means if the student score well in Maths, he/she will score well in ERRW too.

# %%
sat_act.head()
# Out:
#         state region  sat_participation_2019  ebrw_2019  math_2019  \
# 0     Alabama  South                     7.0        583        560
# 1      Alaska   West                    41.0        556        541
# 2     Arizona   West                    31.0        569        565
# 3    Arkansas  South                     6.0        582        559
# 4  California   West                    63.0        534        531
#
#    sat_total_2019  sat_participation_2018  ebrw_2018  math_2018  \
# 0            1143                     6.0        595        571
# 1            1097                    43.0        562        544
# 2            1134                    29.0        577        572
# 3            1141                     5.0        592        576
# 4            1065                    60.0        540        536
#
#    sat_total_2018  ...  act_participation_2018  act_composite_2018  \
# 0            1166  ...                   100.0                19.1
# ...

# %%
# Create a horizontal barplot for the average SAT participation rate per state
plt.subplots(figsize=(16,12))
plt.barh(sat_act['state'], sat_act['ave_sat_participation'], label='SAT', color='dodgerblue', alpha=0.5)
plt.barh(sat_act['state'], sat_act['ave_act_participation'], label='ACT', color='sandybrown', alpha=0.5)

# plot the mean line
plt.axvline(sat_act['ave_sat_participation'].mean(), color='crimson', linestyle='dashed', linewidth=2, label='SAT Ave.')
plt.axvline(sat_act['ave_act_participation'].mean(), color='black', linestyle='dashed', linewidth=2, label='ACT Ave.')

# Set the label
plt.title("SAT and ACT Average Participation Rate from 2017 to 2019 per State", fontsize=16, fontweight='bold')
plt.xlabel("Average Participation Rate %", fontsize=14)

plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')

# Save the plot
plt.savefig('../image/sat_act_ave_part_rate.png')

# %%
sat_act.describe()
# Out:
#        sat_participation_2019   ebrw_2019   math_2019  sat_total_2019  \
# count               51.000000   51.000000   51.000000       51.000000
# mean                49.058824  560.803922  552.196078     1113.078431
# std                 38.747600   46.248035   51.290553       97.197910
# min                  2.000000  483.000000  460.000000      943.000000
# 25%                  5.500000  527.500000  511.500000     1038.000000
# 50%                 54.000000  550.000000  546.000000     1097.000000
# 75%                 82.000000  612.000000  599.000000     1210.000000
# max                100.000000  636.000000  648.000000     1284.000000
#
#        sat_participation_2018   ebrw_2018   math_2018  sat_total_2018  \
# count               51.000000   51.000000   51.000000       51.000000
# mean                45.745098  563.686275  556.235294     1120.019608
# std                 37.314256   47.502627   47.772623       94.155083
# ...

# %%
# Create barplot to the average SAT and ACT participation rate by region
plt.subplots(figsize=(17,6))

plt.subplot(121)
sns.barplot(x='region', y='mean', data=sat_participation_by_region)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Average Participation %', fontsize=14)
plt.title('SAT Average Participation by Regions', loc='center', fontsize=16, fontweight='bold')
plt.ylim(0, 100)

plt.subplot(122)
sns.barplot(x='region', y='mean', data=act_participation_by_region)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Average Participation %', fontsize=14)
plt.title('ACT Average Participation by Regions', loc='center', fontsize=16, fontweight='bold')
plt.ylim(0, 100)

# Save the plot
plt.savefig('../image/sat_act_ave_part_by_region.png')

# %% [markdown]
# **Interpretation 2:**
# - Overall, ACT has a better participation rate than SAT.
# - Participation rate by region interpretation is similar to the points stated in Analysis 6.

# %%
# Create funtion to plot histogram for participation rate
def plot_hist(df, x_axis, xlabel, title, test='SAT'):
    # Specify color for each test    
    if test == 'SAT':
        color = 'dodgerblue'
    else:
        color = 'sandybrown'
        
    # Create histogram
    ax = sns.histplot(data= df, x=x_axis, bins = 20, color=color)

    # Set the labels
    ax.set_xlabel(xlabel)
    ax.set_ylabel('Number of States')
    ax.set_title(title, loc='center', fontsize=16, fontweight='bold');

    # Draw the mean line
    plt.axvline(df[x_axis].mean(), color='crimson', linestyle='dashed', linewidth=2, label='Mean')
    plt.axvline(df[x_axis].median(), color='black', linestyle='dashed', linewidth=2, label='Median')
    plt.legend(loc=0)

# %%
# Create histogram for SAT Participation Rate
plt.figure(figsize=(16, 6))

plt.subplot(131)
plot_hist(sat_act, 'sat_participation_2019', 'Participation Rate (%)', 'SAT 2019 Participation Rate')

plt.subplot(132)
plot_hist(sat_act, 'sat_participation_2018', 'Participation Rate (%)', 'SAT 2018 Participation Rate')

plt.subplot(133)
plot_hist(sat_act, 'sat_participation_2017', 'Participation Rate (%)', 'SAT 2017 Participation Rate')

# Save the plot
plt.savefig('../image/sat_part_histogram.png')

# %%
# Create histogram for ACT Participation Rate
plt.figure(figsize=(16, 6))

plt.subplot(131)
plot_hist(sat_act, 'act_participation_2019', 'Participation Rate (%)', 'ACT 2019 Participation Rate', 'ACT')

plt.subplot(132)
plot_hist(sat_act, 'act_participation_2018', 'Participation Rate (%)', 'ACT 2018 Participation Rate', 'ACT')

plt.subplot(133)
plot_hist(sat_act, 'act_participation_2017', 'Participation Rate (%)', 'ACT 2017 Participation Rate', 'ACT')

# Save the plot
plt.savefig('../image/act_part_histogram.png')

# %%
sat_act[['sat_participation_2019', 'sat_participation_2018', 'sat_participation_2017', \
         'act_participation_2019', 'act_participation_2018', 'act_participation_2017']].describe()
# Out:
#        sat_participation_2019  sat_participation_2018  sat_participation_2017  \
# count               51.000000               51.000000               51.000000
# mean                49.058824               45.745098               39.803922
# std                 38.747600               37.314256               35.276632
# min                  2.000000                2.000000                2.000000
# 25%                  5.500000                4.500000                4.000000
# 50%                 54.000000               52.000000               38.000000
# 75%                 82.000000               77.500000               66.000000
# max                100.000000              100.000000              100.000000
#
#        act_participation_2019  act_participation_2018  act_participation_2017
# count               51.000000               51.000000               51.000000
# mean                58.666667               61.725490               65.254902
# ...

# %% [markdown]
# **Interpretation 3:**
# - Overall, SAT participation rate has improved since 2017 while the number of states with 100% ACT participation rate is relatively consistent. Reasons for the improvement is cited in Analysis 1
# - SAT has a higher number of states with low participation rate. However, we can see there is a slight improvement of 5.95% in 2018 and 3.31% in 2019. There is also a shift in the median in 2018 from 38 to 52 (more towards central of the data).
# - ACT has a higher number of states with high participation rate. However, there is slight decline of 3.52% in 2018 and 3.06% in 2019. This could be due to shift to SAT for some states. The median has also shifted and this shift is more obvious in 2019 from 66 to 54 (more towards left of the data)
# - Both tests do not show a normal distribution. The distribution is more binomial where it has either high participation rate or low participation rate. Since we do not have a normal distribution, this means the condition for the Central Limit Theorem (CLT) is not satisfied where the sample size may not be large enough. If we have more sample data (>=30 samples), then we may achieve a normal distribution based on the Central Limit Theorem.
# - The spread for both tests has increased. For SAT, the standard deviation increased from 35.28 to 38.75. For ACT, the standard deviation increased from 32.14 to 34.52.

# %%
# Create histogram for SAT Total Score
plt.figure(figsize=(16, 6))

plt.subplot(131)
plot_hist(sat_act, 'sat_total_2019', 'Total Score', 'SAT 2019 Total Scores')

plt.subplot(132)
plot_hist(sat_act, 'sat_total_2018', 'Total Score', 'SAT 2018 Total Scores')

plt.subplot(133)
plot_hist(sat_act, 'sat_total_2017', 'Total Score', 'SAT 2017 Total Scores')

# %%
# Create histogram for ACT Total Score
plt.figure(figsize=(16, 6))

plt.subplot(131)
plot_hist(sat_act, 'act_composite_2019', 'Composite Score', 'ACT 2019 Total Scores', test='ACT')

plt.subplot(132)
plot_hist(sat_act, 'act_composite_2018', 'Composite Score', 'ACT 2018 Total Scores', test='ACT')

plt.subplot(133)
plot_hist(sat_act, 'act_composite_2017', 'Composite Score', 'ACT 2017 Total Scores', test='ACT')

# %%
sat_act[['sat_total_2019', 'sat_total_2018', 'sat_total_2017', \
         'act_composite_2019', 'act_composite_2018', 'act_composite_2017']].describe()
# Out:
#        sat_total_2019  sat_total_2018  sat_total_2017  act_composite_2019  \
# count       51.000000       51.000000       51.000000           51.000000
# mean      1113.078431     1120.019608     1126.098039           21.464706
# std         97.197910       94.155083       92.494812            2.194523
# min        943.000000      977.000000      950.000000           17.900000
# 25%       1038.000000     1057.500000     1055.500000           19.800000
# 50%       1097.000000     1098.000000     1107.000000           21.100000
# 75%       1210.000000     1204.000000     1212.000000           23.700000
# max       1284.000000     1298.000000     1295.000000           25.500000
#
#        act_composite_2018  act_composite_2017
# count           51.000000           51.000000
# mean            21.496078           21.519608
# std              2.111583            2.020695
# min             17.700000           17.800000
# 25%             19.950000           19.800000
# ...

# %% [markdown]
# **Interpretation 4:**
# - Slight decrease for the SAT Total score is observed (from 1126 to 1113) and slight decrease in also observed in the median (from 1107 to 1097) and the shift is towards left of the data.
# - The ACT Composite score is more consistent for both mean and median.
# - The distribution is more binomial than normal with no skew observed. Similarly, if there are more sample data, we may achieve a normal distribution based on the Central Limit Theorem.
# - The spread for both tests has increased. For SAT, the standard deviation increased from 92.49 to 97.20. For ACT, the standard deviation increased from 2.02 to 2.19.

# %%
# Filter out the states with > 85% SAT participation rate for the 3 years
sat_high_participation = sat_act.loc[(sat_act['sat_participation_2019'] > 75) & (sat_act['sat_participation_2018'] > 75) \
                                     & (sat_act['sat_participation_2017'] > 75)]
sat_high_participation.shape
# Out:
# (8, 26)

# %%
# Filter out the states with >85% ACT participation rate for the 3 years
act_high_participation = sat_act.loc[(sat_act['act_participation_2019'] > 75) & (sat_act['act_participation_2018'] > 75) \
                                     & (sat_act['act_participation_2017'] > 75)]
act_high_participation.shape
# Out:
# (19, 26)

# %%
# Filter out the states with <15% SAT participation rate for the 3 years
sat_low_participation = sat_act.loc[(sat_act['sat_participation_2019'] < 25) & (sat_act['sat_participation_2018'] < 25) \
                                     & (sat_act['sat_participation_2017'] < 25)]
sat_low_participation.shape
# Out:
# (20, 26)

# %%
# Filter out the states with <15% ACT participation rate for the 3 years
act_low_participation = sat_act.loc[(sat_act['act_participation_2019'] < 25) & (sat_act['act_participation_2018'] > 25) \
                                     & (sat_act['act_participation_2017'] > 25)]
act_low_participation.shape
# Out:
# (3, 26)

# %% [markdown]
# - There are 8 states with more than 75% SAT participation rate and 19 states with more than 75% ACT participation rate.
# - There are 20 states with less than 25% SAT participation rate and 3 states with less than 25% ACT participation rate.

# %%
# Create function to plot boxplot
def plot_boxplot(df, column_list, xticklabel_list, title, ylim_lower,ylim_upper):
    
    # Create the boxplot
    ax = sns.boxplot(data=df[column_list])
    
    # Set the labels
    ax.set_xticklabels(xticklabel_list)
    ax.set_title(title, loc='center', fontsize=16, fontweight='bold')
    ax.set_ylim(ylim_lower,ylim_upper)

# %%
# Create boxplot to see the impact on the high vs low participation rate for SAT Score by Year
plt.figure(figsize=(18,6))

plt.subplot(131)
plot_boxplot(sat_act, ['sat_total_2019', 'sat_total_2018', 'sat_total_2017'], ['2019', '2018', '2017'], \
             'SAT Total Score (Overall)', 900, 1350)

plt.subplot(132)
plot_boxplot(sat_high_participation, ['sat_total_2019', 'sat_total_2018', 'sat_total_2017'], ['2019', '2018', '2017'], \
             'SAT Total Score (>75% Participation)', 900, 1350) 

plt.subplot(133)
plot_boxplot(sat_low_participation, ['sat_total_2019', 'sat_total_2018', 'sat_total_2017'], ['2019', '2018', '2017'], \
             'SAT Total Score (<25% Participation)', 900, 1350)

# Save the plot
plt.savefig('../image/sat_high_low_boxplot.png')

# %% [markdown]
# **Interpretation 5:**
# - In general, states with higher participation rate tends to score lower in the test while those with lower participation rate have a better score. The spread of the data is smaller when the data is filtered by high or low participation rate states. Outliers can be observed as well.
# - For state with lower participation rate, the students who participated are higher performers since the score is higher. However, this does not mean the state has the mostly the top performing students it is a smaller representative of students taking the test and there are outliers observed in the graph.

# %%
# Create boxplot to see the impact on the high vs low participation rate for ACT Score by Year
plt.figure(figsize=(18,6))

plt.subplot(131)
plot_boxplot(sat_act, ['act_composite_2019', 'act_composite_2018', 'act_composite_2017'], ['2019', '2018', '2017'], \
             'ACT (Overall)', 17, 26)

plt.subplot(132)
plot_boxplot(act_high_participation, ['act_composite_2019', 'act_composite_2018', 'act_composite_2017'], \
             ['2019', '2018', '2017'], 'ACT (>75% Participation Rate)', 17, 26)

plt.subplot(133)
plot_boxplot(act_low_participation, ['act_composite_2019', 'act_composite_2018', 'act_composite_2017'], \
             ['2019', '2018', '2017'], 'ACT (<25% Participation Rate)', 17, 26)

# Save the plot
plt.savefig('../image/act_high_low_boxplot.png')

# %% [markdown]
# **Interpretation 6:**
# - Similar to SAT, states with higher participation rate tends to score lower in the test while those with lower participation rate have a better score. However, the spread of the data is smaller when the data is filtered by high participation rate states while low participation rate states has a bigger spread. No outliers observed for ACT.
# - Similar to SAT, for state with lower participation rate, the students who participated are higher performers since the score is higher. However, this does not means the the state has the mostly the top performing students it is a small representative of students taking the test and we observed that the spread is bigger even though there is no outlier.

# %%
# Create function to plot scatter
def plot_scatter(df, x, y, xlabel, ylabel, title):
    # Create the scatterplot
    ax = sns.scatterplot(data=df, x=x, y=y)

    # Set the labels
    ax.set_xlabel(xlabel, fontsize=14)
    ax.set_ylabel(ylabel, fontsize=14)
    ax.set_title(title, loc='center', fontsize=16, fontweight='bold')

# %%
# Create scatterplot to see the relationship between SAT 2019/2018 and 2018/2017
plt.figure(figsize=(15,6))

plt.subplot(121)
plot_scatter(sat_act, 'sat_total_2018', 'sat_total_2019', '2018 Total Score', '2019 Score', \
             'Relationship between 2019 & 2018 SAT Total Score')

plt.subplot(122)
plot_scatter(sat_act, 'sat_total_2017', 'sat_total_2018', '2017 Total Score', '2018 Score', \
             'Relationship between 2018 & 2017 SAT Total Score')

# Save the plot
plt.savefig('../image/SAT_score_relationship.png')

# %%
# Create scatterplot to see the relationship between ACT score for 2019/2018 and 2018/2017
plt.figure(figsize=(15,6))

plt.subplot(121)
plot_scatter(sat_act, 'act_composite_2018', 'act_composite_2019', '2018 Composite Score', '2019 Composite Score', \
             'Relationship between 2019 & 2018 ACT Composite Score')

plt.subplot(122)
plot_scatter(sat_act, 'act_composite_2017', 'act_composite_2018', '2017 Composite Score', '2018 CompositeScore', \
             'Relationship between 2018 & 2017 ACT Composite Score')

# Save the plot
plt.savefig('../image/ACT_score_relationship.png')

# %% [markdown]
# **Interpretation 7:**
# - The relationship for each test has a strong correlation year by year. This implies state that has done well this year is likely to do well again in the next year. This correlation is stronger for the ACT test as the scores are relatively similarly across the years. This observation is also seen from the correlation matrix in the heatmap.

# %%
# Create scatterplot to see the relationship between SAT 2019 participation rate and SAT score
plt.figure(figsize=(10,5))
plot_scatter(sat_act, 'sat_participation_2019', 'sat_total_2019', 'Participation Rate (%)', '2019 Total Score', \
             'Relationship between SAT Participation Rate and Total Score (2019)')

# Save the plot
plt.savefig('../image/SAT_score_part_2019.png')

# %%
# Create scatterplot to see the relationship between SAT 2018 participation rate and SAT score
plt.figure(figsize=(10,5))
plot_scatter(sat_act, 'sat_participation_2018', 'sat_total_2018', 'Participation Rate (%)', '2018 Total Score', \
             'Relationship between SAT Participation Rate and Total Score (2018)')

# Save the plot
plt.savefig('../image/SAT_score_part_2018.png')

# %%
# Create scatterplot to see the relationship between SAT 2017 participation rate and SAT score
plt.figure(figsize=(10,5))
plot_scatter(sat_act, 'sat_participation_2018', 'sat_total_2017', 'Participation Rate (%)', '2017 Total Score', \
             'Relationship between SAT Participation Rate and Total Score (2017)')

# Save the plot
plt.savefig('../image/SAT_score_part_2017.png')

# %% [markdown]
# **Interpretation 8:**
# - The participation rate and score is inversely related. A higher participation rate has a lower score while lower participation rate has a higher score.
# - A cluster of data is observed at lower and higher participation rate for SAT scores.

# %%
# List states that have average SAT participation between 40 to 70%
sat_act[['state', 'region', 'ave_sat_participation', 'ave_act_participation']][(sat_act['ave_sat_participation'] < 70) & \
                                                                               (sat_act['ave_sat_participation'] > 40)]\
                                                                                .sort_values(by='region')
# Out:
#              state     region  ave_sat_participation  ave_act_participation
# 13        Illinois    Midwest                 69.333                 57.000
# 14         Indiana    Midwest                 64.000                 32.000
# 38    Pennsylvania  Northeast                 68.333                 20.000
# 45         Vermont  Northeast                 63.333                 24.333
# 10         Georgia      South                 67.333                 52.333
# 33  North Carolina      South                 50.667                100.000
# 40  South Carolina      South                 57.667                 92.667
# 43           Texas      South                 65.333                 43.000
# 46        Virginia      South                 67.000                 24.667
# 48   West Virginia      South                 47.000                 61.000
# 1           Alaska       West                 40.667                 45.333
# ...

# %% [markdown]
# **Interpretation 9:**
# - South and West regions are potential areas to focus on their participation rate improvement.
# - Suggested states include Texas, Virginia and California as these states currently do not have any compulsory requirement.

# %%
# Subset the participation rate data to Colorado and Illinois
impact_states = sat_act[['state', 'region', 'sat_participation_2019', 'sat_participation_2018', 'sat_participation_2017', 'act_participation_2019', 'act_participation_2018', 'act_participation_2017']][(sat_act['state'] == 'Colorado') | (sat_act['state'] == 'Illinois')]
impact_states.set_index('state', inplace=True)
impact_states
# Out:
#            region  sat_participation_2019  sat_participation_2018  \
# state
# Colorado     West                   100.0                   100.0
# Illinois  Midwest                   100.0                    99.0
#
#           sat_participation_2017  act_participation_2019  \
# state
# Colorado                    11.0                    27.0
# Illinois                     9.0                    35.0
#
#           act_participation_2018  act_participation_2017
# state
# Colorado                    30.0                   100.0
# Illinois                    43.0                    93.0

# %%
# Plot bar chart to see the Colorado and Illinois SAT participation rate in 2017 to 2019
ax1 = impact_states[['sat_participation_2019', 'sat_participation_2018', 'sat_participation_2017']].plot(kind='barh')
ax1.set_title('Colorado & Illinois SAT Participation', loc='center', fontsize=16, fontweight='bold')
ax1.set_xlabel('Participation Rate %')

# Save the plot
plt.savefig('../image/colorado_illinois_sat.png')

# %%
# Plot bar chart to see the Colorado and Illinois ACT participation rate in 2017 to 2019
ax2 = impact_states[['act_participation_2019', 'act_participation_2018', 'act_participation_2017']].plot(kind='barh')
ax2.set_title('Colorado & Illinois ACT Participation', loc='center', fontsize=16, fontweight='bold')
ax2.set_xlabel('Participation Rate %')

# Save the plot
plt.savefig('../image/colorado_illinois_act.png')

# %% [markdown]
# **Interpretation 10:**
# - Colorado and Illinois are two examples where their participation rate improved tremendously when both states implemented compulsory SAT test.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Key takeaways:**
# - From the data, there is an increase in the SAT participation rates since 2017. Other than the change in the SAT format, the SAT School Day and  benefits of the fee wavier attributed to the success of increasing participation. However, ACT is currently still the preferred choice.
# - The test score is inversely related to the participation where a high participation rate implies a lower test score. With a higher participation, the test score may have a bigger spread which will affects the average of the score.
# - The relationship for either SAT or ACT has a strong correlation year by year. This implies state that has done well this year is likely to do well again in the next year.
# - SAT fares better in Northeast region while ACT fares better in the other 3 regions. We can see the impact of the compulsory test on the participation rate. Colorado and Illinois are two cases where SAT participation rate improved tremendously when the states require the students to take the SAT test.
#
# **Recommendations:**
#
# To further increase the SAT participation rate, the College Board may consider:
# - To work with the states to offer SAT as a mandatory requirement and provide programs to help the school to administer the test in an efficient way and allows the students to sit for the test conveniently. College Board can consider focusing on states that have 40 to 70% SAT participation rates. Some suggested states are Texas, Virginia and California.
# - To work with states that currently require students to take either SAT or ACT. North Carolina is recommended as it has ~ 50% participation rate even though it ACT participation rate is 100%. South Carolina is also recommended as it SAT participation rate has increased in 2019.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
